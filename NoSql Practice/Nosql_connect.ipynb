# %%
import pandas as pd
import cassandra
print(cassandra.__version__)
# Out:
# 3.28.0

# %%
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider
import json

# This secure connect bundle is autogenerated when you download your SCB, 
# if yours is different update the file name below
cloud_config= {
  'secure_connect_bundle': 'C:/Users/Asus/NoSQL Practice/secure-connect-puranik-db.zip'
}

# This token JSON file is autogenerated when you download your token, 
# if yours is different update the file name below
with open("C:/Users/Asus/NoSQL Practice/Puranik_DB-token.json") as f:
    secrets = json.load(f)

CLIENT_ID = secrets["clientId"]
CLIENT_SECRET = secrets["secret"]

auth_provider = PlainTextAuthProvider(CLIENT_ID, CLIENT_SECRET)
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect()

row = session.execute("select release_version from system.local").one()
if row:
  print(row[0])
else:
  print("An error occurred.")
# Out:
# 4.0.11-c7d4aa9d7ae5

# %%
query = "use keyspace_1"
session.execute(query)

# %%
query = "select * from athlete_events"
result = session.execute(query)
for row in result:
    print(row)
# Out:
# Row(ID=23, Name='Fritz Aanes', Height=187, Weight=89, Age=26, City='Athina', Event="Wrestling Men's Light-Heavyweight, Greco-Roman", Games='2004 Summer', Medal='NA', NOC='NOR', Season='Summer', Sex='M', Sport='Wrestling', Team='Norway', Year=2004)
# Row(ID=114, Name='Essa Abbas Faleh Hashem', Height=160, Weight=65, Age=20, City='Moskva', Event="Athletics Men's Long Jump", Games='1980 Summer', Medal='NA', NOC='KUW', Season='Summer', Sex='M', Sport='Athletics', Team='Kuwait', Year=1980)
# Row(ID=53, Name='Talaat Abada', Height=172, Weight=58, Age=24, City='Sydney', Event="Taekwondo Men's Flyweight", Games='2000 Summer', Medal='NA', NOC='EGY', Season='Summer', Sex='M', Sport='Taekwondo', Team='Egypt', Year=2000)
# Row(ID=110, Name='Abubakar Abbas Abbas', Height=175, Weight=66, Age=20, City='Rio de Janeiro', Event="Athletics Men's 400 metres", Games='2016 Summer', Medal='NA', NOC='BRN', Season='Summer', Sex='M', Sport='Athletics', Team='Bahrain', Year=2016)
# ...

# %%
query = "select * from noc_regions"
result = session.execute(query)
for row in result:
    print(row)
# Out:
# Row(NOC='IOA', region='Individual Olympic Athletes', notes='Individual Olympic Athletes')
# Row(NOC='AHO', region='Curacao', notes='Netherlands Antilles')
# Row(NOC='BOH', region='Czech Republic', notes='Bohemia')
# Row(NOC='CRT', region='Greece', notes='Crete')
# Row(NOC='HKG', region='China', notes='Hong Kong')
# Row(NOC='ISV', region='Virgin Islands, US', notes='Virgin Islands')
# Row(NOC='ANT', region='Antigua', notes='Antigua and Barbuda')
# Row(NOC='ANZ', region='Australia', notes='Australasia')
